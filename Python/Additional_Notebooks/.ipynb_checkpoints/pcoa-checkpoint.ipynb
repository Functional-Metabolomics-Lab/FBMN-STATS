# %% [markdown]
# # Data Clean up
#
# Updated on: 2022-10-17 16:54:01 CEST
#
# Authors: Abzer Kelminal (abzer.shah@uni-tuebingen.de), Axel Walter, Carolina Gonzalez <br>
# Input file format: .csv files or .txt files <br>
# Outputs: .csv files <br>
# Dependencies: pandas <br>
#
# This Notebook is used for cleaning the feature table, an output of metabolomics experiment, containing all the features with their corresponding intensities. The data cleanup steps involved are: 1) Blank removal 2) Imputation 3) Normalisation. Each step would be discussed in detail later.
#
# This Notebook can be run with both Jupyter Notebook & Google Colab. Please read the comments before proceeding with the code and let us know if you run into any errors and if you think it could be commented better. We would highly appreciate your suggestions and comments!!
#
# # About the Test data:
#
# The files used in this tutorial are part of an interlab comparison study, where different laboratories around the world analysed the same environmental samples on their respective LC-MS/MS equipments. To simulate algal bloom, standardized algae extracts (A) in marine dissovled organic matter (M) at different concentrations were prepared (450 (A45M), 150 (A15M), and 50 (A5M) ppm A). Samples were then shipped to different laboratories for untargeted LC-MS/MS metabolomics analysis. In this tutorial we are working with one of the datasets, which was acquired on a UHPLC system coupled to a Thermo Scientific Q Exactive HF Orbitrap LC-MS/MS mass spectrometer. MS/MS data were acquired in data-dependent acquisition (DDA) with fragmentation of the five most abundant ions in the spectrum per precursor scan. Data files were subsequently preprocessed using MZmine3 and the feature-based molecular networking workflow in GNPS.

# %% [markdown]
# # Package installation:

# %%
# !pip install scipy==1.8.1
# !pip install plotly scikit-bio
# Out:
# Requirement already satisfied: scipy==1.8.1 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (1.8.1)
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in /home/axel/.local/lib/python3.10/site-packages (from scipy==1.8.1) (1.23.4)
# Requirement already satisfied: plotly in /home/axel/.local/lib/python3.10/site-packages (5.9.0)
# Requirement already satisfied: scikit-bio in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (0.5.7)
# Requirement already satisfied: tenacity>=6.2.0 in /home/axel/.local/lib/python3.10/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: lockfile>=0.10.2 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from scikit-bio) (0.12.2)
# Requirement already satisfied: matplotlib>=1.4.3 in /home/axel/.local/lib/python3.10/site-packages (from scikit-bio) (3.5.2)
# Requirement already satisfied: pandas>=1.0.0 in /home/axel/.local/lib/python3.10/site-packages (from scikit-bio) (1.5.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from scikit-bio) (1.0.2)
# Requirement already satisfied: CacheControl>=0.11.5 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from scikit-bio) (0.12.11)
# Requirement already satisfied: IPython>=3.2.0 in /home/axel/.local/lib/python3.10/site-packages (from scikit-bio) (8.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from scikit-bio) (3.7.0)
# Requirement already satisfied: numpy>=1.9.2 in /home/axel/.local/lib/python3.10/site-packages (from scikit-bio) (1.23.4)
# Requirement already satisfied: natsort>=4.0.3 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from scikit-bio) (8.2.0)
# Requirement already satisfied: decorator>=3.4.2 in /home/axel/.local/lib/python3.10/site-packages (from scikit-bio) (5.1.1)
# Requirement already satisfied: scipy>=1.3.0 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from scikit-bio) (1.8.1)
# Requirement already satisfied: hdmedians>=0.14.1 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from scikit-bio) (0.14.2)
# Requirement already satisfied: msgpack>=0.5.2 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from CacheControl>=0.11.5->scikit-bio) (1.0.4)
# Requirement already satisfied: requests in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from CacheControl>=0.11.5->scikit-bio) (2.28.1)
# Requirement already satisfied: Cython>=0.23 in /home/axel/.local/lib/python3.10/site-packages (from hdmedians>=0.14.1->scikit-bio) (0.29.30)
# Requirement already satisfied: jedi>=0.16 in /home/axel/.local/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio) (0.18.1)
# Requirement already satisfied: pickleshare in /home/axel/.local/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /home/axel/.local/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio) (0.1.3)
# Requirement already satisfied: pygments>=2.4.0 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio) (2.13.0)
# Requirement already satisfied: backcall in /home/axel/.local/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio) (65.5.0)
# Requirement already satisfied: traitlets>=5 in /home/axel/.local/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio) (5.3.0)
# Requirement already satisfied: pexpect>4.3 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/axel/.local/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio) (3.0.30)
# Requirement already satisfied: stack-data in /home/axel/.local/lib/python3.10/site-packages (from IPython>=3.2.0->scikit-bio) (0.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/axel/.local/lib/python3.10/site-packages (from matplotlib>=1.4.3->scikit-bio) (1.4.3)
# Requirement already satisfied: packaging>=20.0 in /home/axel/.local/lib/python3.10/site-packages (from matplotlib>=1.4.3->scikit-bio) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/axel/.local/lib/python3.10/site-packages (from matplotlib>=1.4.3->scikit-bio) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from matplotlib>=1.4.3->scikit-bio) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/axel/.local/lib/python3.10/site-packages (from matplotlib>=1.4.3->scikit-bio) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from matplotlib>=1.4.3->scikit-bio) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/axel/.local/lib/python3.10/site-packages (from matplotlib>=1.4.3->scikit-bio) (4.34.4)
# Requirement already satisfied: pytz>=2020.1 in /home/axel/.local/lib/python3.10/site-packages (from pandas>=1.0.0->scikit-bio) (2022.4)
# Requirement already satisfied: joblib>=0.11 in /home/axel/.local/lib/python3.10/site-packages (from scikit-learn>=0.19.1->scikit-bio) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/axel/.local/lib/python3.10/site-packages (from scikit-learn>=0.19.1->scikit-bio) (3.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/axel/.local/lib/python3.10/site-packages (from jedi>=0.16->IPython>=3.2.0->scikit-bio) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from pexpect>4.3->IPython>=3.2.0->scikit-bio) (0.7.0)
# Requirement already satisfied: wcwidth in /home/axel/.local/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython>=3.2.0->scikit-bio) (0.2.5)
# Requirement already satisfied: six>=1.5 in /home/axel/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->scikit-bio) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from requests->CacheControl>=0.11.5->scikit-bio) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from requests->CacheControl>=0.11.5->scikit-bio) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from requests->CacheControl>=0.11.5->scikit-bio) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /home/axel/miniconda3/envs/r-to-python/lib/python3.10/site-packages (from requests->CacheControl>=0.11.5->scikit-bio) (3.4)
# Requirement already satisfied: executing in /home/axel/.local/lib/python3.10/site-packages (from stack-data->IPython>=3.2.0->scikit-bio) (0.9.1)
# Requirement already satisfied: asttokens in /home/axel/.local/lib/python3.10/site-packages (from stack-data->IPython>=3.2.0->scikit-bio) (2.0.5)
# Requirement already satisfied: pure-eval in /home/axel/.local/lib/python3.10/site-packages (from stack-data->IPython>=3.2.0->scikit-bio) (0.2.2)

# %%
# installing necessary packages (omitted for now)

# importing necessary modules
import pandas as pd
import numpy as np
import os
import plotly.express as px
import matplotlib.pyplot as plt
import skbio

from scipy.spatial.distance import pdist, squareform
from scipy.spatial import distance
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

from ipywidgets import interact

# %% [markdown]
# # PCA:

# %%
# open a feature dataframe with imputed and scaled values
imputed_s = pd.read_csv('imputed_s.tsv', sep='\t').set_index("Unnamed: 0")
# open the matching metadata file
md_samples = pd.read_csv('md_samples.tsv', sep='\t').set_index("Unnamed: 0")

# %%
merged_data = pd.merge(md_samples, imputed_s, left_index=True, right_index=True)
merged_data.head()
# Out:
#                                               ATTRIBUTE_Sample  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML             A15M
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML             A15M
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML             A15M
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML             A45M
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML             A45M
#
#                                               ATTRIBUTE_Sample_Type  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML                Sample
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML                Sample
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML                Sample
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML                Sample
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML                Sample
#
#                                                ATTRIBUTE_Time-Point  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML                  15.0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML                  15.0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML                  15.0
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML                  45.0
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML                  45.0
#
#                                                1458_150.128_3.194  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML            1.628980
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML           -0.543722
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML           -1.084394
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML           -0.279449
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML           -0.350608
#
#                                                1418_150.128_3.173  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML           -1.053124
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML            0.324533
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML            0.720872
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML            0.086509
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML            0.512217
#
#                                                30_151.035_0.653  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML         -1.020978
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML         -1.153552
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML          0.514123
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML         -1.573132
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML          0.566929
#
#                                                7137_151.075_6.002  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML            1.348525
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML            1.356302
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML            1.525673
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML           -1.084736
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML           -1.085550
#
#                                                6905_151.075_5.937  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML            0.441509
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML            0.545070
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML            0.642921
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML           -1.303003
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML           -1.373272
#
#                                                5684_151.075_5.554  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML            1.651623
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML            1.140705
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML            1.010851
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML           -1.453874
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML           -1.520887
#
#                                                4120_151.075_5.025  ...  \
# Unnamed: 0                                                         ...
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML            0.187444  ...
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML            1.376215  ...
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML            0.557715  ...
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML           -1.704643  ...
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML           -1.818895  ...
#
#                                                90_770.851_0.705  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML         -0.485050
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML         -0.578428
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML         -0.701652
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML          1.379181
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML          0.500670
#
#                                                16880_774.609_12.932  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML             -0.050817
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML             -0.493004
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML             -0.280701
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML              2.195786
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML              1.767888
#
#                                                16869_776.625_12.233  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML             -0.309721
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML              3.315775
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML             -0.227047
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML             -0.309721
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML             -0.309721
#
#                                                14833_782.541_9.242  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML            -0.527895
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML            -0.570459
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML            -0.528371
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML             1.974547
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML             1.663683
#
#                                                16914_808.525_14.316  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML              -0.56542
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML              -0.56542
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML              -0.56542
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML              -0.56542
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML              -0.56542
#
#                                                16922_810.54_14.323  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML             0.433955
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML            -0.623779
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML             0.372539
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML             2.214279
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML            -0.609766
#
#                                                16913_824.52_14.314  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML            -0.570665
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML            -0.570665
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML            -0.570665
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML            -0.570665
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML            -0.570665
#
#                                                86_838.838_0.705  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML         -0.174226
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML         -1.231997
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML         -0.614848
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML          1.146465
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML          0.334642
#
#                                                16935_852.551_14.321  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML             -0.549442
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML             -0.028349
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML             -0.052354
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML             -0.549442
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML              2.668665
#
#                                                80_906.826_0.705
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML          0.320186
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML         -1.252695
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML         -1.206147
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML          1.326451
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML          0.081857
#
# [5 rows x 3606 columns]

# %% [markdown]
# ## imputed_s was already scaled - do we need to to it again?

# %%
#transformed data
# trans_data = StandardScaler().fit_transform(imputed_s)

#calculating Principal components
n = 5
pca = PCA(n_components=n)
pca_df = pd.DataFrame(data = pca.fit_transform(imputed_s), columns = [f'PC{x}' for x in range(1, n+1)])
pca_df.index = md_samples.index
pca_df
# Out:
#                                                      PC1        PC2  \
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML -34.220333 -25.358305
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML -37.048456 -29.357718
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML -37.835252 -30.059551
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML  66.660832  -9.184186
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML  66.551429 -11.622051
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep3.mzML  66.386880  -9.201951
# DOM_Interlab-LCMS_Lab1_A5M_Pos_MS2_rep1.mzML   -5.704333  56.754609
# DOM_Interlab-LCMS_Lab1_A5M_Pos_MS2_rep2.mzML   -8.498028  17.019133
# DOM_Interlab-LCMS_Lab1_A5M_Pos_MS2_rep3.mzML   -7.309008  20.122238
# DOM_Interlab-LCMS_Lab1_M_Pos_MS2_rep1.mzML    -22.088166   6.479618
# DOM_Interlab-LCMS_Lab1_M_Pos_MS2_rep2.mzML    -23.112414   7.580062
# DOM_Interlab-LCMS_Lab1_M_Pos_MS2_rep3.mzML    -23.783152   6.828101
#
#                                                      PC3        PC4        PC5
# Unnamed: 0
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep1.mzML  14.866447  -1.984973 -20.153902
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep2.mzML  14.396593   0.306494  14.121997
# DOM_Interlab-LCMS_Lab1_A15M_Pos_MS2_rep3.mzML  14.299632  13.199799   7.130750
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep1.mzML   2.361366  -7.754506  -8.131249
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep2.mzML   2.711660   2.122439   6.691030
# DOM_Interlab-LCMS_Lab1_A45M_Pos_MS2_rep3.mzML  -0.113552   0.666145   2.589000
# DOM_Interlab-LCMS_Lab1_A5M_Pos_MS2_rep1.mzML   41.816351  -3.125428   3.808121
# DOM_Interlab-LCMS_Lab1_A5M_Pos_MS2_rep2.mzML  -17.058609  20.457882 -10.517224
# DOM_Interlab-LCMS_Lab1_A5M_Pos_MS2_rep3.mzML  -22.113799  23.797493   6.095314
# DOM_Interlab-LCMS_Lab1_M_Pos_MS2_rep1.mzML    -12.931901 -10.868099 -15.126714
# DOM_Interlab-LCMS_Lab1_M_Pos_MS2_rep2.mzML    -15.255003 -17.046361 -12.134629
# DOM_Interlab-LCMS_Lab1_M_Pos_MS2_rep3.mzML    -22.979184 -19.770885  25.627505

# %% [markdown]
# ## no need to combine since they are already in the same order in the pca_df and md_samples?

# %%
def pca_scatter_plot(attribute):
    title = f'PRINCIPLE COMPONENT ANALYSIS'
    
    df = pd.merge(pca_df[['PC1', 'PC2']], md_samples[attribute].apply(str), left_index=True, right_index=True)
    # display(df)
    fig = px.scatter(df, x='PC1', y='PC2', template='plotly_white', width=600, height=400, color=attribute)

    fig.update_layout(font={"color":"grey", "size":12, "family":"Sans"},
                      title={"text":title, 'x':0.2, "font_color":"#3E3D53"},
                      xaxis_title=f'PC1 {round(pca.explained_variance_ratio_[0]*100, 1)}%',
                      yaxis_title=f'PC2 {round(pca.explained_variance_ratio_[1]*100, 1)}%')
    fig.show()
    
    # To get a scree plot showing the variance of each PC in percentage:
    percent_variance = np.round(pca.explained_variance_ratio_* 100, decimals =2)

    fig = px.bar(x=pca_df.columns, y=percent_variance, template="plotly_white",  width=500, height=400)
    fig.update_traces(marker_color="#696880", width=0.5)
    fig.update_layout(font={"color":"grey", "size":12, "family":"Sans"},
                      title={"text":"PCA - VARIANCE", 'x':0.5, "font_color":"#3E3D53"},
                      xaxis_title="principal component", yaxis_title="variance (%)")
    fig.show()

interact(pca_scatter_plot, attribute=sorted(md_samples.columns))
# Out:
# interactive(children=(Dropdown(description='attribute', options=('ATTRIBUTE_Sample', 'ATTRIBUTE_Sample_Type', …
# <function __main__.pca_scatter_plot(attribute)>

# %% [markdown]
# ## Principle Coordinate Analysis (PCoA)

# %%
def pcoa(attribute, distance_matrix):
    # Create the distance matrix from the original data
    distance_matrix = skbio.stats.distance.DistanceMatrix(distance.squareform(distance.pdist(imputed_s.values, distance_matrix)))
    # perform PERMANOVA test
    permanova = skbio.stats.distance.permanova(distance_matrix, md_samples['ATTRIBUTE_Sample'])
    permanova['R2'] = 1 - 1 / (1 + permanova['test statistic'] * permanova['number of groups'] / (permanova['sample size'] - permanova['number of groups'] - 1))
    display(permanova)
    # perfom PCoA
    pcoa = skbio.stats.ordination.pcoa(distance_matrix)
    df = pcoa.samples[['PC1', 'PC2']]
    df = df.set_index(md_samples.index)
    df = pd.merge(df[['PC1', 'PC2']], md_samples[attribute].apply(str), left_index=True, right_index=True)
    
    title = f'PRINCIPLE COORDINATE ANALYSIS'
    fig = px.scatter(df, x='PC1', y='PC2', template='plotly_white', width=600, height=400, color=attribute)

    fig.update_layout(font={"color":"grey", "size":12, "family":"Sans"},
                      title={"text":title, 'x':0.18, "font_color":"#3E3D53"},
                      xaxis_title=f'PC1 {round(pcoa.proportion_explained[0]*100, 1)}%',
                      yaxis_title=f'PC2 {round(pcoa.proportion_explained[1]*100, 1)}%')
    fig.show()
    
    # To get a scree plot showing the variance of each PC in percentage:
    percent_variance = np.round(pcoa.proportion_explained* 100, decimals =2)

    fig = px.bar(x=[f'PC{x}' for x in range(1, len(pcoa.proportion_explained)+1)], y=percent_variance, template="plotly_white",  width=500, height=400)
    fig.update_traces(marker_color="#696880", width=0.5)
    fig.update_layout(font={"color":"grey", "size":12, "family":"Sans"},
                      title={"text":"PCoA - VARIANCE", 'x':0.5, "font_color":"#3E3D53"},
                      xaxis_title="principal component", yaxis_title="variance (%)")#
    fig.show()

matrices = ['canberra', 'chebyshev', 'correlation', 'cosine', 'euclidean', 'hamming', 'jaccard', 'matching', 'minkowski', 'seuclidean']
interact(pcoa, attribute=sorted(md_samples.columns), distance_matrix=matrices)
# Out:
# interactive(children=(Dropdown(description='attribute', options=('ATTRIBUTE_Sample', 'ATTRIBUTE_Sample_Type', …
# <function __main__.pcoa(attribute, distance_matrix)>

# %%
dm = skbio.stats.distance.DistanceMatrix(distance.squareform(distance.pdist(imputed_s.values, 'canberra')))

# %%
p = skbio.stats.distance.permanova(dm, md_samples['ATTRIBUTE_Sample'])
r2 = 1 - 1 / (1 + p['test statistic'] * p['number of groups'] / (p['sample size'] - p['number of groups'] - 1))
p["R2"] = r2
print(p)
# Out:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      12
# number of groups                  4
# test statistic               5.7346
# p-value                       0.001
# number of permutations          999
# R2                         0.766187
# Name: PERMANOVA results, dtype: object
